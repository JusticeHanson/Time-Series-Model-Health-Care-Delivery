# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
import pandas as pd

# Load data without specifying 'parse_dates' and 'index_col' initially
file_path = 'D:\\JHanson\\Justice Hanson\\DS Career Accelerator\\Time-Series-Model-Health-Care-Delivery\\data\\synthetic_healthcare_data.csv'
df = pd.read_csv(file_path)

# Convert 'birthdate' to datetime format
df['birthdate'] = pd.to_datetime(df['birthdate'])

# Set 'birthdate' column as index
df.set_index('birthdate', inplace=True)

df.head()
# Out:
#                      Name  Age  Patient_Visits  Blood_Pressure  \
# birthdate
# 2008-06-01  Thomas Harris   80              12      107.053185
# 1994-07-12   Joseph Frank   68               6      131.608268
# 1998-05-30     Erik Braun   75              11      115.322988
# 2002-05-02   Terri Gibson   35              14      123.465039
# 2008-03-01   Jeffrey Shaw   44               7      119.530794
#
#             Medication_Adherence  Hospital_Admissions  Weight_kg   Height_cm  \
# birthdate
# 2008-06-01              0.510912                    3  59.977830  169.353114
# 1994-07-12              0.831895                    1  62.475648  170.728741
# 1998-05-30              0.981697                    2  55.332148  170.731970
# 2002-05-02              0.780084                    1  64.985979  168.497570
# 2008-03-01              0.968411                    4  79.753125  181.917075
#
#            Smoking_Status  Exercise_Minutes  Diet_Quality  Stress_Level  \
# birthdate
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 500 entries, 2008-06-01 to 1994-12-13
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  500 non-null    object
#  1   Age                   500 non-null    int64
#  2   Patient_Visits        500 non-null    int64
#  3   Blood_Pressure        500 non-null    float64
#  4   Medication_Adherence  500 non-null    float64
#  5   Hospital_Admissions   500 non-null    int64
#  6   Weight_kg             500 non-null    float64
#  7   Height_cm             500 non-null    float64
#  8   Smoking_Status        500 non-null    object
#  9   Exercise_Minutes      500 non-null    int64
#  10  Diet_Quality          500 non-null    float64
#  11  Stress_Level          500 non-null    float64
#  12  Cholesterol           500 non-null    float64
#  13  marital               500 non-null    object
# ...

# %%
df.describe().T
# Out:
#                       count        mean        std         min         25%  \
# Age                   500.0   49.718000  17.894438   18.000000   34.000000
# Patient_Visits        500.0    9.910000   3.228428    1.000000    8.000000
# Blood_Pressure        500.0  120.791281  10.141942   91.037446  113.893122
# Medication_Adherence  500.0    0.752532   0.143190    0.500783    0.637835
# Hospital_Admissions   500.0    2.000000   1.399971    0.000000    1.000000
# Weight_kg             500.0   70.520207  10.472133   40.705513   62.464826
# Height_cm             500.0  169.404569   9.899333  141.609213  162.873499
# Exercise_Minutes      500.0   59.840000   7.809506   40.000000   54.000000
# Diet_Quality          500.0    2.956110   1.173378    1.005713    1.928948
# Stress_Level          500.0    5.385252   2.520755    1.002169    3.253039
# Cholesterol           500.0  181.222530  29.868081   98.621623  160.998447
#
#                              50%         75%         max
# ...

# %%
df.duplicated().sum()
# Out:
# 0
